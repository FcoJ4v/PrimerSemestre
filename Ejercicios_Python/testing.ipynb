# %%
import numpy as np 
opc = 0
a_normal = 78900
a_vip = 24000

from google.colab import drive
drive.mount('/content/drive/')

# %run '/content/drive/My Drive/testing_funciones.ipynb'

print('\t Bienvenido a VUELOS-DUOC')

"try:"
while opc != 5:
  opc = int(input('1)Ver asientos disponibles\n2)Comprar asiento\n3)Anular vuelo\n4)Modificar vuelo\n5)Salir\n'))
  if opc == 1:
    ver_asiento()
    
  elif opc == 2:
    print('opc2')

  elif opc ==3:
    print('opc3')

  elif opc ==4:
    print('opc4')
  elif opc ==5:
    print('cerrando sesion')
  else:
    print('opc ingresada no valida, vuelva a intentar\n')
"""except:
  print('OOPS, ALGO SALIO MAL')"""
# Out:
# Mounted at /content/drive/
# 	 Bienvenido a VUELOS-DUOC
# 1)Ver asientos disponibles
# 2)Comprar asiento
# 3)Anular vuelo
# 4)Modificar vuelo
# 5)Salir
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-637dfc4b2eb5> in <module>()
#      15   opc = int(input('1)Ver asientos disponibles\n2)Comprar asiento\n3)Anular vuelo\n4)Modificar vuelo\n5)Salir\n'))
#      16   if opc == 1:
# ---> 17     ver_asiento()
#      18
#      19   elif opc == 2:
#
# <ipython-input-1-be88397b22f5> in ver_asiento()
#      39                   arreglin_asiento[1][3],
#      40                   arreglin_asiento[1][4],
# ---> 41                   arreglin_asiento[1][5]))
#
# IndexError: tuple index out of range
