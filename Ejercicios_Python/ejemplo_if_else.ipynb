# %%
#condicion
#si - finsi

edad = int(input("ingrese su edad: "))
if(edad>17):
  print(f"su edad es:{edad}")
else: 
  print(f"su edad es: {edad}, es menor de edad")

if(edad>17 and edad<50):
  print(f"su edad es:{edad}")
elif(edad >50):
  print(f"Su edad es:{edad}, usted es adulto mayor")
else:
    print(f"su edad es: {edad}, usted es menor de edad")
# Out:
# ingrese su edad: 1
# su edad es: 1, es menor de edad
# su edad es: 1, usted es menor de edad
