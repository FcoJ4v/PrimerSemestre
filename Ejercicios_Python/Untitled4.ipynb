# %%
|opc = 0
bandera_rut = False
bandera_edad = False
bandera_genero = False
bandera_tipo_sus = False
bandera_correo = False
lista_rut = []
lista_nombre = []
lista_direccion = []
lista_comuna = []
lista_correo = []
lista_edad = []
lista_genero = []
lista_tipos_sus = []

try:
  while opc !=4:
    print("Juan Maestro APP\n")
    opc = int(input("\tSeleccione una opcion:\n\n1)Registrar Cliente\n2)Suscripcion\n3)Consultar Datos Cliente\n4)Salir\n"))
   #ver while en rut
    if(opc == 1):
      while bandera_rut == False:
        print("Registro de Clientes.\n")
        rut = int(input("Rut:\n"))
        nombre = (input("Nombre:\n"))
        direccion = input("Direccion:\n")
        comuna = input("Comuna:\n")
        correo = input("Correo:\n")
        edad = int(input("Edad:\n"))
        genero = input("Genero: (M o F)\n")
        tipo_sus = input("Tipo suscripcion: GOLD - PREMIUM - SILVER\n")
      else:
        print("nope")
        if (rut >= 4000000 and rut <= 99999999):
          print("El rut ingresado es valido")
          bandera_rut = True
        else:
          print("Rut ingresado no valido.")
        if (edad >= 0 or edad <= 110):
          print("La edad ingresada es valida.")
          bandera_edad = True
        else:
          print("La edad ingresada no es valida.")
        if(genero =="m" or genero =="f" ):
          print("El genero ingresado es valido")
          bandera_genero = True
        else:
          print("El genero ingresado no es valido")
        if(tipo_sus == "gold" or tipo_sus =="premium" or tipo_sus=="silver"):
          print("Suscripcion ingresada valida")
          bandera_tipo_sus = True
        else:
          print("suscripcion ingresada no valida")
        for caracter in correo:
          if (caracter =="@"):
            print("El correo ingresado es valido.")
            bandera_correo = True
          else:
            print("El correo ingresado no es valido.")

            
                
            
    elif(opc ==2):
      solicita_rut = int(input("Ingrese el rut del cliente:\n"))
    elif(opc ==3 ):
      print("opc3")
      

except:
  print ("Algo salio Mal, Vuelve a intentarlo")
# Out:
# Juan Maestro APP
#
# 	Seleccione una opcion:
#
# 1)Registrar Cliente
# 2)Suscripcion
# 3)Consultar Datos Cliente
# 4)Salir
# 1
# Registro de Clientes.
#
# Rut:
# x
# Algo salio Mal, Vuelve a intentarlo
