# %%
# a or b

a = True
b = True
c = False
d = True
e = False


if ( a or b):
  print('Verdadero')
# Out:
# Verdadero

# %%
# a or c

if(a or c):
  print ('verdadero')
# Out:
# verdadero

# %%
# a and e

if(a and e):
  print('verdadero')
else:
    print ('falso')
# Out:
# falso

# %%
# (a or e) and b

if (a or e) and b:
  print('verdadero')
# Out:
# verdadero

# %%
flag_agua = False

respuesta = input('andas con la caña?\n')

if(respuesta == "si"):
  flag_agua == True

if (flag_agua):
  print('Que rico es tomar agua el domingo a las 11:00')
# Out:
# andas con la caña?
# si
