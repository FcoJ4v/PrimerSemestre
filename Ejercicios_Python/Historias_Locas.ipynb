# %%
#Ejercicio Historias Locas

adj = input("Adjetivo: ")
verbo1 = input ("Verbo: ")
verbo2 = input ("Verbo:")
sustantivo_plural = input("Sustantivo en Plural: ")

Histlocas = f"¡Programar es tan {adj}!. Siempre me emociona porque me encanta {verbo1} problemas. ¡Aprende a {verbo2} con nosotros y alcanza tus {sustantivo_plural}! "

print(Histlocas)
