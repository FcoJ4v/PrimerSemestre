# %%
#EJERCICIO 1
cliente = 0
opc_entrada=0
cant_entrada=0
opc_palomitas=0
selec_palomita=0
cant_palomita=0
opc_bebida=0
selec_bebida=0
cant_bebida=0
total_bebida=0
calc_dcto=0

print("Bienvenido al Sistema de ventas de CINEDUOC \n")
cliente = int(input('Seleccione una opcion:\n 1)DUOC\n 2)General \n'))
if (cliente==1):
  cli_opcion= int(input('Seleccione una opcion:\n 1)Estudiante\n 2)Funcionrio \n'))
elif(cliente==2):
  print('Bienvenido Invitado')
opc_entrada = int(input('Seleccione un tipo de entrada:\n 1)Estreno -> $4.800 \n 2)Normal -> $2.900\n'))
cant_entrada=int(input('Ingrese la cantidad de entradas: \n'))

#palomitas

opc_palomitas=int(input('¿Desea agregar palomitas de maiz a su pedido? \n 1)Si \n 2)No \n'))
if (opc_palomitas==1):
  selec_palomita=int(input(' Seleccione una de nuestras promociones: \n 1)Palomita Pequeña -> $2.500 \n 2)Palomita Mediana -> $4.500 \n 3)Palomita Grande -> $7.800 \n'))
  cant_palomita=int(input('Ingrese la cantidad de palomitas:\n'))
elif (opc_palomitas<=0 or opc_palomitas>2):
  print('Opcion Ingresada no valida')

#bebidas

opc_bebida=int(input('¿Desea agregar una Bebida a su pedido? \n 1)Si \n 2)No\n'))
if(opc_bebida==1):
  selec_bebida=int(input('Seleccione una de nuestras promociones: \n 1)Bebida Pequeña -> $1.000 \n 2)Bebida Mediana -> $1.250 \n 3)Bebida Grande -> $2.000 \n'))
  cant_bebida=int(input('Ingrese la cantidad de Bebidas:\n'))
elif (opc_bebida<=0 or opc_bebida>2):
  print('Opcion Ingresada no valida')

#calculos
#calculo de palomitas

if(selec_palomita==1):
  total_palomita= (2500 * cant_palomita)
elif(selec_palomita==2):
  total_palomita=(4500 * cant_palomita)
elif(selec_palomita==3):
  total_palomita=(7800 * cant_palomita)

#calculo bebida
if(selec_bebida==1):
  total_bebida= (1000*cant_bebida)
elif(selec_bebida==2):
  total_bebida=(1250*cant_bebida)
elif(selec_bebida==3):
  total_bebida=(2000*cant_bebida)
#Calculo si es personal DUOC/General y seleccion entrada Estreno

if(cliente==1  and opc_entrada==1):
  calc_porcen = int(4800 * 0.30)
  calc_dcto=int (4800-calc_porcen)*cant_entrada
  total_vta= (total_palomita + total_bebida + calc_dcto)
  print(f'El total de la venta es: ${total_vta}')
elif (cliente==2 and opc_entrada==1):
  total_vta=(total_palomita+total_bebida+4800)*cant_entrada
  print(f'El total de la venta es: ${total_vta}')

#Calculo si es personal DUOC/General y seleccion entrada Normal

if(cliente==1 and  opc_entrada==2):
  calc_porcen = int(2900 * 0.30)
  calc_dcto=int (2900-calc_porcen)*cant_entrada
  total_vta= (total_palomita + total_bebida + calc_dcto)
  print(f'El total de la venta es: ${total_vta}')
elif (cliente==2 and opc_entrada==2):
  total_vta=(total_palomita+total_bebida+2900)*cant_entrada
  print(f'El total de la venta es: ${total_vta}')

#calculo de vuelto

pago=int(input('Ingrese la cantidad de dinero pagada:\n'))
calc_vuelto=(pago-total_vta)
print(f'El vuelto a entregar es: \n${calc_vuelto}')
# Out:
# Bienvenido al Sistema de ventas de CINEDUOC
#
# Seleccione una opcion:
#  1)DUOC
#  2)General
# 1
# Seleccione una opcion:
#  1)Estudiante
#  2)Funcionrio
# 1
# Seleccione un tipo de entrada:
#  1)Estreno -> $4.800
#  2)Normal -> $2.900
# 1
# Ingrese la cantidad de entradas:
# 1
# ¿Desea agregar palomitas de maiz a su pedido?
#  1)Si
#  2)No
# 1
#  Seleccione una de nuestras promociones:
#  1)Palomita Pequeña -> $2.500
#  2)Palomita Mediana -> $4.500
#  3)Palomita Grande -> $7.800
# 1
# Ingrese la cantidad de palomitas:
# 1
# ¿Desea agregar una Bebida a su pedido?
#  1)Si
#  2)No
# 1
# Seleccione una de nuestras promociones:
#  1)Bebida Pequeña -> $1.000
#  2)Bebida Mediana -> $1.250
#  3)Bebida Grande -> $2.000
# 1
# Ingrese la cantidad de Bebidas:
# 1
# El total de la venta es: $6860
# Ingrese la cantidad de dinero pagada:
# 10000
# El vuelto a entregar es:
# $3140
