# %%
opciones = 0
bandera_rut = False
bandera_edad = False
bandera_sexo = False
bandera_ps = False
bandera_correo = False
lista_rut = []
lista_nombre = []
lista_direccion = []
lista_correo = []
lista_edad = []
lista_sexo = []
lista_registro = []
lista_ps = []
lista_fecha = []
contador=0
c = 0
try:
  while opciones !=4:
    print("Centro Medico DUOC")

    opciones =int(input("1)REGISTRO PACIENTE\n2)ATENCION PACIENTE\n3)CONSULTAR DATOS PACIENTE\n4)SALIR\n"))
    if(opciones ==1):
      rut = int(input("Ingresar RUT sin guion ni puntos:"))
      nombre = input("Ingrese el nombre del paciente:\n")
      direccion = input("Ingresar direccion:\n")
      correo = input("Ingresar correo:\n")
      edad = int(input("Ingresar edad:\n"))
      sexo = input("Ingresar sexo (F O M):\n")
      registro = " "
      ps = input("Isapre o fonasa:\n")


      if (rut >=5000000 and rut<99999999):
        print("RUT VALIDO.")
        bandera_rut = True
      else:
        print("RUT NO VALIDO")

      if(edad >0 and edad <=110):
        print("EDAD VALIDA")
        bandera_edad = True
      else:
          print("EDAD NO VALIDA")
      if(sexo =="f" or sexo=="m"):
        print("SEXO VALIDO")
        bandera_sexo = True
      else:
        print("SEXO NO VALIDO")
      if (ps =="isapre" or ps=="fonasa"):
        print("PS VALIDA")
        bandera_ps = True
      else:
        print("PS NO VALIDO")
      
        for caracter in correo:
          if correo =="@":

            print("Correo valido")
            bandera_correo = True
            
          else:
            print("Correo no valido")
      if bandera_rut and bandera_edad:
        lista_rut.append(rut)
        lista_nombre.append(nombre)
        lista_direccion.append(direccion)
        lista_correo.append(correo)
        lista_edad.append(edad)
        lista_sexo.append(sexo)
        lista_registro.append(registro)
        lista_ps.append(ps)
      
    elif(opciones ==2):
      print("ATENCION PACIENTE\n")
      ingrese_rut=int(input("Ingrese RUT del paciente:\n"))
      for recorre_rut in lista_rut:
        if (recorre_rut == ingrese_rut):
          print("RUT REGISTRADO.")
          bandera_rut = True
          fecha = input("")
          lista_fecha.append(fecha)

          observacion = input(" Ingrese los sintomas:\n")
          lista_registro = (f"Rut:{lista_rut},Fecha: {lista_fecha},Observacion: {observacion}")
        else:
          print("Rut NO EXISTE.")
    elif(opciones ==3):
      print("Consulta de Pacientes.")
      ingrese_rut=int(input("Ingrese RUT del paciente:\n"))
      for recorre_rut in lista_rut:
        if (recorre_rut == ingrese_rut):
          c= contador
          print("RUT REGISTRADO.")
          bandera_rut = True
          print(f"RUT: {lista_rut[c]}\nNOMBRE:{lista_nombre[c]}\nDIRECCION:{lista_direccion[c]}\nCORREO:{lista_correo[c]}\nEDAD:{lista_edad[c]}\nSEXO:{lista_sexo[c]}\nREGISTRO:{lista_registro[c]}\nPREVISION_SALUD:{lista_ps[c]}")
          contador = contador + 1
        else:
          print("RUT INGRESADO NO REGISTRADO.")
    elif(opciones ==4):
      print("Gracias por preferirnos")
    else:
      print("opcion ingresada no valida, vuelva a intentarlo.\n")
except:
  print("Algo salio mal.")
# Out:
# Centro Medico DUOC
# 1)REGISTRO PACIENTE
# 2)ATENCION PACIENTE
# 3)CONSULTAR DATOS PACIENTE
# 4)SALIR
# 1
# Ingresar RUT sin guion ni puntos:18466331
# Ingrese el nombre del paciente:
# francisco
# Ingresar direccion:
# nueva direccion 123
# Ingresar correo:
# correo@correo
# Ingresar edad:
# 21
# Ingresar sexo (F O M):
# m
# Isapre o fonasa:
# isapre
# RUT VALIDO.
# EDAD VALIDA
# SEXO VALIDO
# PS VALIDA
# Centro Medico DUOC
# 1)REGISTRO PACIENTE
# 2)ATENCION PACIENTE
# 3)CONSULTAR DATOS PACIENTE
# 4)SALIR
# 1
# Ingresar RUT sin guion ni puntos:6855955
# Ingrese el nombre del paciente:
# maria
# Ingresar direccion:
# vieja direccion
# Ingresar correo:
# correo@aaa
# Ingresar edad:
# 54
# Ingresar sexo (F O M):
# f
# Isapre o fonasa:
# fonasa
# RUT VALIDO.
# EDAD VALIDA
# SEXO VALIDO
# PS VALIDA
# Centro Medico DUOC
# 1)REGISTRO PACIENTE
# 2)ATENCION PACIENTE
# 3)CONSULTAR DATOS PACIENTE
# 4)SALIR
# 3
# Consulta de Pacientes.
# Ingrese RUT del paciente:
# 18466331
# RUT REGISTRADO.
# ...
