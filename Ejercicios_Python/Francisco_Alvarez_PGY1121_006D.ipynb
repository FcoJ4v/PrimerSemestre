# %%
from google.colab import drive
drive.mount('/content/drive/')

# %run '/content/drive/My Drive/FranciscoAlvarez_PGY1121_006D_Funciones.ipynb'

opc = 0
print('\t Bienvenido al Sistema de AUTO SEGURO ')

#try
while opc !=4:
  opc = int(input('1)GRABAR\n2)BUSCAR\n3)IMPRIMIR CERTIFICADOS\n4)SALIR\n'))
  if opc ==1:
    opc_grabar()
    
  elif opc ==2:
    opc_buscando()
    
  elif opc ==3:
    opc_imp_cert()
    
  elif opc ==4:
    print('Cerrando sesion. Francisco Alvarez U, Version: 1.0')
  else:
    print('La opcion ingresada no es valida, Vuelva a intentar')

  

#except
#  print('OOPS!.Algo salio mal.')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# 	 Bienvenido al Sistema de AUTO SEGURO
# 1)GRABAR
# 2)BUSCAR
# 3)IMPRIMIR CERTIFICADOS
# 4)SALIR
# 1
# 	 Bienvenido a la opcion GRABAR.
#
# Ingrese el tipo de vehiculo:
# sadad
# Ingrese la patente del vehiculo:
# asdf12
# Ingrese la marca del vehiculo:
# asdada
# Ingrese el precio del vehiculo
# 6000000
# Ingrese Multas (Monto y Fecha (DD/MM/AA)):
#
# Ingrese fecha de registro del vehiculo:
# dadas
# Ingrese el nombre del dueño:
# sdadsad
# Patente ingresada es valida
# no valido
# no valido
# no valido
# no valido
# no valido
# no valido
# 1)GRABAR
# 2)BUSCAR
# 3)IMPRIMIR CERTIFICADOS
# 4)SALIR
# 4
# Cerrando sesion. Francisco Alvarez U, Version: 1.0
