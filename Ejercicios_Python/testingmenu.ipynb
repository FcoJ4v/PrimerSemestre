# %%
from google.colab import drive
drive.mount('/content/drive/')

# %run '/content/drive/My Drive/testing_funciones.ipynb'


opc = 0

print("\tBIENVENIDO AL SISTEMA DE AUTO SEGURO")

#try:
while opc != 4:
  opc = int(input("1) GRABAR\n2) BUSCAR\n3) IMPRIMIR CERTIFICADO\n4) SALIR\n"))
  if opc==1:
    opc_grabar()
  elif opc==2:
    opc_buscando()
  elif opc==3:
    print("opc3")
  elif opc==4:
    print("FIN DE SESION,")
  else:
    print("OPCION INGRESADA NO VALIDA, VUELA A INTENTARLO")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# 	BIENVENIDO AL SISTEMA DE AUTO SEGURO
# 1) GRABAR
# 2) BUSCAR
# 3) IMPRIMIR CERTIFICADO
# 4) SALIR
# 1
# TIPO DE VEHICULO:
# sda
# PATENTE:
# aaaa11
# MARCA:
# sadsad
# PRECIO:
# 6000000
# MONTO Y FECHA (DD/MM/AA)123123
# FECHA REGISTRO VEHICULO123123
# NOMBRE DEL DUEÑOdasdsa
# Patente ingresada es valida
# valido
# 1) GRABAR
# 2) BUSCAR
# 3) IMPRIMIR CERTIFICADO
# 4) SALIR
# 2
# 	 BUSCAR AUTOMOVIL.
#
# Ingresa la patente del vehiculo:
# aaaa11
# EL VEHICULO EXISTE EN EL SISTEMA.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-cb99e6ac9d26> in <module>()
#      15     opc_grabar()
#      16   elif opc==2:
# ---> 17     opc_buscando()
#      18   elif opc==3:
#      19     print("opc3")
#
# ...
