# %%
opc = 0
try:
  while opc !=4:
    print ("\tJuan Mestro APP")
    opc = int(input("1)REGISTRAR CLIENTES\n2)SUSCRIPCION\n3)CONSULTAR DATOS CLIENTE\n4)SALIR\n"))
    if(opc ==1):
      rut = int(input("Ingrese el rut:\n"))
      if(rut >4000000 and rut >99999999):
        print("RUT VALIDO.")
      nombre = input("Ingrese el nombre:\n")
      direccion = input("Ingrese direccion:\n")
      comuna = input("Ingrese comuna:\n")
      correo = input("Ingrese correo:\n")
      edad = int(input("Ingrese edad:\n"))
      genero = input("Ingrese Genero (H O M):\n")
      celular = int(input("Ingrese numero celular:\n"))
      tipo_usuario = input("Ingrese el tipo de usuario:\n")

except:
  print("oops! ALGO SALIO MAL.")
# Out:
# 	Juan Mestro APP
