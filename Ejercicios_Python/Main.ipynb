# %%
x ="\\\"
print(len(x))
# Out:
#   File "<ipython-input-2-328547a2b896>", line 1
#     x = "\\\"
#              ^
# SyntaxError: EOL while scanning string literal

# %%
print(chr(ord('p')+2))
# Out:
# r

# %%
print(float("1.3"))
# Out:
# 1.3

# %%
class A:
  def __init__(self,v=2):
    self.v = v

  def set(self,v=1):
    self.v = v
    return self.v

a = A()
b=a
b.set()
print(a.v)
# Out:
# 1

# %%
class A:
  A = 1
  def __init__(self):
    self.a = 0

print(hasattr(A,'a'))
# Out:
# False

# %%
class A:
  def __unit__(self):
    pass
a = A(1)
print(hasattr(a,'A'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-9b29ccf8b0c6> in <module>()
#       2   def __unit__(self):
#       3     pass
# ----> 4 a = A(1)
#       5 print(hasattr(a,'A'))
#
# TypeError: A() takes no arguments
