# %%
rut = int(input("Ingrese rut: "))
nombre = input("Ingrese nombre: ")
direccion = input("Ingrese direccion: ")
correo = input("Ingrese correo: ")
edad = int(input("Ingrese edad: "))
sexo = input("Ingrese sexo: ")
registros = input("Ingrese registros: ")
ps = input("Ingrese ps: ")
# Out:
# Ingrese rut: 600000
# Ingrese nombre: h
# Ingrese direccion: hjjhkjh
# Ingrese correo: jjkjhkj
# Ingrese edad: 67
# Ingrese sexo: hjhj
# Ingrese registros: ljhjjhjh
# Ingrese ps: iuuih

# %%
if (rut >= 5000000 and rut < 100000000):
  print("rut valido")
nombre = input("Ingrese nombre: ")
direccion = input("Ingrese direccion: ")
correo = input("Ingrese correo: ")
if int(edad) >-1 and int(edad) < 110:
  print("edad valido")
sexo = input("Ingrese sexo: ")
registros = input("Ingrese registros: ")
ps = input("Ingrese ps: ")

# %%
lista_rut = []
lista_edad = []
#append, agrega elementos a la lista en este caso el rut
lista_rut.append(rut)
lista_edad.append(edad)

print(lista_rut)
print(lista_edad)

# %%
opcion = 0
bandera_rut = False
bandera_edad  = False
bandera_correo = False
lista_rut = []
lista_nombre =[]
lista_edad= []
lista_correo= []
lista_direccion =[]
lista_correo=[]
lista_edad=[]
lista_sexo=[]
lista_registros=[]
lista_ps=[]
contador_posicion = 0

x = 0


while opcion != 4:
  print("1)registro\n2)opcion2\n3)opcion3\n4)salir\n")
  opcion = int(input("Ingrese una opcion: "))
  if opcion == 1:
    rut = int(input("Ingrese rut: "))
    nombre = input("Ingrese nombre: ")
    direccion = input("Ingrese direccion: ")
    correo = input("Ingrese correo: ")
    edad = int(input("Ingrese edad: "))
    sexo = input("Ingrese sexo: ")
    registros = " "
    ps = input("Ingrese ps: ")

  if (rut >= 5000000 and rut < 100000000):
    print("rut valido")
    bandera_rut = True

  if int(edad) >-1 and int(edad) < 110:
    print("edad valido")
    bandera_edad = True

  for caracter in correo:  
    if caracter =="@":
      print("correo valido")
      bandera_correo = True
  
  if bandera_rut and bandera_edad:
    
    #almacenamiento de datos en una lista
    lista_rut.append(rut)
    lista_nombre.append(nombre)
    lista_edad.append(edad)
    lista_correo.append(correo)
    lista_direccion.append(direccion)
    lista_sexo.append(sexo)
    lista_registros.append(registros)
    lista_ps.append(ps)

  if opcion == 2:
    rut_solicitado = int(input("Ingrese rut buscado: "))
    for rut_recorrido in lista_rut:
      if(rut_recorrido == rut_solicitado):
        print("rut existe")

        fecha = input("")
        motivo = input("")

        lista_registro = "{}{}{}".format(lista_registro[x],fecha,motivo)

  if opcion==3:
     rut_solicitado = int(input("Ingrese rut buscado: "))
     for rut_recorrido in lista_rut:
      
      if(rut_recorrido == rut_solicitado):
         print("rut existe\n\n")
         x = contador_posicion

         print("{}\n{}<'n{}\n{}\n{}\n{}\n{}\n{}".format(lista_rut[x], lista_nombre[x],lista_edad[x],lista_correo[x],lista_direccion[x],lista_sexo[x],lista_registros[x],lista_ps[x]))
      contador_posicion = contador_posicion +1

print(lista_rut)
# Out:
# 1)registro
# 2)opcion2
# 3)opcion3
# 4)salir
#
# Ingrese una opcion: 1
# Ingrese rut: 184666331
# Ingrese nombre: asdsssad
# Ingrese direccion: adsasd3weqeweqw
# Ingrese correo: wasds@saasdas
# Ingrese edad: 212
# Ingrese sexo: f
# Ingrese ps: asdads
# correo valido
# 1)registro
# 2)opcion2
# 3)opcion3
# 4)salir
#
# Ingrese una opcion: 1
# Ingrese rut: 68559553
# Ingrese nombre: asdasdqweqeqweqwe
# Ingrese direccion: qweqweqweqwe
# Ingrese correo: qweqwe@weqwe
# Ingrese edad: 85
# Ingrese sexo: f
# Ingrese ps: wasdasd
# rut valido
# edad valido
# correo valido
# 1)registro
# 2)opcion2
# 3)opcion3
# 4)salir
#
# Ingrese una opcion: 3
# rut valido
# edad valido
# correo valido
# Ingrese rut buscado: 68559553
# rut existe
#
#
# 68559553
# asdasdqweqeqweqwe<'n85
# qweqwe@weqwe
# qweqweqweqwe
# f
#
# wasdasd
# rut existe
#
#
# 68559553
# asdasdqweqeqweqwe<'n85
# qweqwe@weqwe
# qweqweqweqwe
# f
#
# wasdasd
# 1)registro
# 2)opcion2
# 3)opcion3
# 4)salir
#
# Ingrese una opcion: 3
# ...

# %% [markdown]
# Condiciones
# -contadores, acumuladores y bandera
# -for y while
# -validaciones y menu
# -listas
