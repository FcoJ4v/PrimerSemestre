# %%
print('Bienvenidos a MAD LIBS')

cant_jugador = int(input('Ingrese la cantidad de jugadores (1 a 3)): \n'))

if(cant_jugador == 1):
    jugador1 = input("Jugador 1, Ingresa tu nombre: \n")
    lugar = input("Ingresa una lugar\n")
    animal = input("Ingresa tipo de animal\n")
    parte_del_cuerpo = input("Ingresa una parte del cuerpo\n")
    print(f"{jugador1} En esta cueva hace mas frio que en {lugar}. Incluso con la piel del {animal} mas caliente no consigo que mi {parte_del_cuerpo} deje de tiritar ")

elif(cant_jugador ==2):
    jugador1 = input("Jugador 1, Ingresa tu nombre: \n")
    lugar = input("Ingresa una lugar\n")
    animal = input("Ingresa tipo de animal\n")
    parte_del_cuerpo = input("Ingresa una parte del cuerpo\n")

    jugador2 = input("Jugador 2, Ingresa tu nombre: \n")
    adjetivo2 = input("Ingresa un adjetivo\n")
    ciudad2 = input("Ingresa una ciudad\n")
    sustantivo2 = input("Ingresa un sustantivo\n")
    accion1_2 = input("Ingresa una accion\n")
    accion2_2 = input("Ingresa una accion\n")
    accion3_2 = input("Ingresa una accion\n")
    deporte = input("Ingresa un objeto de deporte\n")

    print(f"{jugador1} En esta cueva hace mas frio que en {lugar}. Incluso con la piel del {animal} mas caliente no consigo que mi {parte_del_cuerpo} deje de tiritar ")
    print(f"{jugador2} Haz creado esta Historia!:\nFue muy divertido. {accion1_2} en {ciudad2} y {accion2_2} .")

elif(cant_jugador ==3):
    jugador1 = input("Jugador 1, Ingresa tu nombre: \n")
    adjetivo = input("Ingresa un adjetivo\n")
    ciudad = input("Ingresa una ciudad\n")
    lugar = input("Ingresa una lugar\n")
    sustantivo = input("Ingresa un sustantivo\n")
    accion = input("Ingresa una accion\n")
    deporte = input("Ingresa un objeto de deporte\n")

    jugador2 = input("Jugador 2, Ingresa tu nombre: \n")
    adjetivo2 = input("Ingresa un adjetivo\n")
    ciudad2 = input("Ingresa una ciudad\n")
    sustantivo2 = input("Ingresa un sustantivo\n")
    accion1_2 = input("Ingresa una accion\n")
    accion2_2 = input("Ingresa una accion\n")
    accion3_2 = input("Ingresa una accion\n")
    deporte = input("Ingresa un objeto de deporte\n")

    jugador3 = input("Jugador 3, Ingresa tu nombre: \n")
    adjetivo3 = input("Ingresa un adjetivo\n")
    ciudad3 = input("Ingresa una ciudad\n")
    sustantivo3 = input("Ingresa un sustantivo\n")
    accion1_3 = input("Ingresa una accion\n")
    accion2_3 = input("Ingresa una accion\n")
    accion3_3 = input("Ingresa una accion\n")
    deporte3 = input("Ingresa un objeto de deporte\n")

    
    print(f"{jugador1} Haz creado esta Historia:\nUn dia mi {sustantivo} y yo decidimos ir al {lugar}. Despues decidimos jugar {deporte}. Fue un dia muy {adjetivo}.\n ")
    print(f"{jugador2} Haz creado esta Historia!:\nFue muy divertido. {accion1_2} en {ciudad2} y {accion2_2} .\n")
    print(f"{jugador3} Haz creado esta Historia!:\nFue muy divertido. {accion1_2} en {ciudad2} y {accion2_2} .")
else:
  print('Opcion Ingresada no valida.')
# Out:
# Bienvenidos a MAD LIBS
# Ingrese la cantidad de jugadores (1 a 3)):
# 3
# Jugador 1, Ingresa tu nombre:
# juan
# Ingresa un adjetivo
# sdasdas
# Ingresa una ciudad
# fqscqasa
# Ingresa una lugar
# sdsdasdasd
# Ingresa un sustantivo
# assdasdad
# Ingresa una accion
# assdasdasdasd
# Ingresa un objeto de deporte
# asdasdasdad
# Jugador 2, Ingresa tu nombre:
# ana
# Ingresa un adjetivo
# ssdasdasd
# Ingresa una ciudad
# asdassaq3asdasd
# Ingresa un sustantivo
# asdasdqw3sd
# Ingresa una accion
# asdasdasdasdasd
# Ingresa una accion
# 33qasdsqsdas
# Ingresa una accion
# sq3ssqw
# Ingresa un objeto de deporte
# cwsasd
# Jugador 2, Ingresa tu nombre:
# asdcqzxcqw
# Ingresa un adjetivo
# qwe2wasad
# Ingresa una ciudad
# 3qwddsas
# Ingresa un sustantivo
# eassq3wdwasd
# Ingresa una accion
# qqweqweasd
# Ingresa una accion
# 3qwewdsd
# Ingresa una accion
# qwqwe2324ds
# Ingresa un objeto de deporte
# 3233dsasddas
# juan Haz creado esta Historia:
# ...
