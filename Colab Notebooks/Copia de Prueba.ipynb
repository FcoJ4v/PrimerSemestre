# %%
opc= 0
print("\tBienvenido al sistema de SERVIEXPRESS\n")
try:
  while opc !=4:
    opc = int(input("1)REGISTRAR AUTOMOVIL\n2)REGISTRO MANTENIMIENTO\n3)COSULTAR AUTOMOVIL\n4)SALIR\n"))
    if opc ==1:
      print("Bienvenido a la opcion REGISTRAR AUTOMOVIL.\n")
      patente = input("Ingrese la patente del vehiculo:\n")
      marca = input("Ingrese la marca del vehiculo:\n")
      modelo = input("Ingrese el modelo del vehiculo:\n")
      anio_fab = input("Ingrese año de fabricacion del vehiculo:\n")#validar entre 1900 y 2021
      tipo_vehiculo = input("Ingrese tipo de vehiculo\nB = Bencina\nD = Diesel\nE= Electrico\nH = Hibrido\n")
      registros = input("Ingrese un registro:\n")
    elif opc ==2:
      print("")
    elif opc ==3:
      print("")
    elif opc ==4:
      print("")
    else:
      print("OPCION INGRESADA NO VALIDA.")
except:
  print("ALGO SALIO MAL")
# Out:
# 	Bienvenido al sistema de SERVIEXPRESS
#
# ALGO SALIO MAL
