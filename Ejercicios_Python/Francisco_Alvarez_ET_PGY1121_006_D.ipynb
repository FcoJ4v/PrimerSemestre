# %%
from google.colab import drive
drive.mount('/content/drive/')
opc = 0
# %run '/content/drive/My Drive/Francisco_Alvarez_ET_PGY1121_006_D_FUNCIONES.ipynb'

print("\tBIENVENIDO AL SISTEMA DE VENTAS CREATIVOS.CL")


#try
while opc !=5:
  opc = int(input('1)COMPRAR ENTRADAS\n2)MOSTRAR UBICACIONES DISPONIBLES\n3)VER LISTADO ASISTENTES\n4)GANANCIAS TOTALES\n5)SALIR.\n'))
  if opc ==1:
    compro_entradas()
    
  elif opc ==2:
    muestro_asientos()
    
  elif opc ==3:
    asistentes()    
  elif opc ==4:
    ganancia_tot()
   
  elif opc ==5:
     print('Cerrando sesion. Francisco Alvarez U, 08/07/2022')

  else:
    print('La opcion ingresada no es valida, Vuelva a intentar')

  

#except
#  print('OOPS!.Algo salio mal.')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /content/drive/My Drive/Francisco_Alvarez_ET_PGY1121_006_D_FUNCIONES.ipynb in <module>()
#       8 lista_asientos = []
#       9 lista_rut=[]
# ---> 10 lista_entraad
#      11 contando = 0
#      12
#
# NameError: name 'lista_entraad' is not defined
# 	BIENVENIDO AL SISTEMA DE VENTAS CREATIVOS.CL
# 1)COMPRAR ENTRADAS
# 2)MOSTRAR UBICACIONES DISPONIBLES
# 3)VER LISTADO ASISTENTES
# 4)GANANCIAS TOTALES
# 5)SALIR.
# 5
# Cerrando sesion. Francisco Alvarez U, 08/07/2022
