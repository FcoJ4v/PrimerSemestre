# %%
opc = 0
bandera_patente = False
bandera_anio_fab = False
bandera_tipo_vehiculo = False
bandera_marca = False
lista_patente = []
lista_anio_fab = []
lista_tipo_vehiculo = []
lista_marca = []
lista_modelo = []
lista_fecha = []
lista_observacion = []
lista_reg = []
conteo = 0

print("\tBienvenido al sistema de SERVIEXPRESS\n")
try:
  while opc !=4:
    opc = int(input("1)REGISTRAR AUTOMOVIL\n2)REGISTRO MANTENIMIENTO\n3)COSULTAR AUTOMOVIL\n4)SALIR\n"))
    if opc ==1:
      print("Bienvenido a la opcion REGISTRAR AUTOMOVIL.\n")
      patente = input("Ingrese la patente del vehiculo:\n")
      marca = input("Ingrese la marca del vehiculo:\n")
      modelo = input("Ingrese el modelo del vehiculo:\n")
      anio_fab = int(input("Ingrese año de fabricacion del vehiculo:\n"))
      tipo_vehiculo = input("Ingrese tipo de vehiculo\nB = Bencina\nD = Diesel\nE= Electrico\nH = Hibrido\n")
      registros = input("Ingrese un registro:\n")
      #patente debe contener 6 caracteres, formato aa1000/bbbb10 , agregar bandera
      #for formato in patente:
      # if len(formato) == 6:
        #  print("valido")
        #else:
        # print("no valido")   
          
      #Año de fabricación debe ser un número entero que se encuentre en el rango 1900 2021
      if (anio_fab >=1900 and anio_fab <=2021): #OK
        print("LA FECHA INGRESADA ES VALIDA.\n")
        bandera_anio_fab = True
      else:
        print("LA FECHA INGRESADA NO ES VALIDA.\n")
      #Tipo vehículo debe ser un carácter que sólo acepta las letras: d/b/e/h (mayúscula y minúscula).
      if(tipo_vehiculo == "d" or tipo_vehiculo =="D" or tipo_vehiculo=="b" or tipo_vehiculo=="B" or tipo_vehiculo =="e" or tipo_vehiculo=="E" or tipo_vehiculo=="h" or tipo_vehiculo=="H"):
        print("EL TIPO DE VEHICULO INGRESADO ES VALIDO.\n")
        bandera_tipo_vehiculo = True
      else:
        print("EL TIPO DE VEHICULO INGRESADO NO ES VALIDO.\n")
      
      #Marca no debe estar vacio *
      for caracter in marca:
        if marca !=" ":
          print("DATO INGRESADO CORRECTAMENTE\n")
          bandera_marca = True
        else:
          print("CAMPO MARCA DEBE TENER ALGUN DATO\n.")

      #Modelo no debe estar vacío*
      for caracter_m in modelo:
        if modelo !=" ":
          print("DATO INGRESADO CORRECTAMENTE\n")
          bandera_modelo = True
        else:
          print("CAMPO MODELO DEBE TENER ALGUN DATO.\n")

      #si esta ok guarde datos de cada variable en cada lista. FALTA LA BANDERA DE PATENTE
      if bandera_tipo_vehiculo:
        lista_patente.append(patente)
        lista_anio_fab.append(anio_fab)
        lista_tipo_vehiculo.append(tipo_vehiculo)
        lista_marca.append(marca)
        lista_modelo.append(modelo)


    elif opc ==2:
      print("\tBienvenido al REGISTRO DE MANTENIMIENTO.")
      verifica_patente = input("Ingresa la patente a verificar:\n")#OK
      for ver_patente in lista_patente:
        if(ver_patente == verifica_patente):
          print("LA PATENTE EXISTE EN EL SISTEMA.")
          fecha = input("Ingrese fecha Mantenimiento: DIA/MES/AÑO.\n")
          observacion = input("Ingrese alguna observacion:\n")
          lista_fecha.append(fecha)
          lista_observacion.append(observacion)
          #concatenando registros anteriores con nuevos
          lista_reg = (f"{lista_reg[conteo]},{fecha},{observacion}")
        else:
          print("LA PATENTE INGRESADA NO ESTA REGISTRADA EN EL SISTEMA.\n")
    elif opc ==3:
      print("\tCONSULTAR AUTOMOVIL.\n")
      verifica_patente = input("Ingresa la patente a verificar:\n")#OK
      for ver_patente in lista_patente:
        if(ver_patente == verifica_patente):
          print("LA PATENTE EXISTE EN EL SISTEMA.\n")
          print(f"PATENTE:{lista_patente[conteo]}")
          print(f"MARCA:{lista_marca[conteo]}")
          print(f"MODELO:{lista_modelo[conteo]}")
          print(f"AÑO_FABRICACION:{lista_anio_fab[conteo]}")
          print(f"TIPO_VEHICULO:{lista_tipo_vehiculo[conteo]}")
          conteo = conteo +1
          #print(f"REGISTROS:{lista_[conteo]}")
                  
        else:
          print("LA PATENTE INGRESADA NO ESTA REGISTRADA EN EL SISTEMA.\n")
    elif opc ==4:
      print("CERRANDO SESION")
    else:
      print("OPCION INGRESADA NO VALIDA.VUELVA A INTENTARLO.\n")
except:
  print("ALGO SALIO MAL")
# Out:
# 	Bienvenido al sistema de SERVIEXPRESS
#
# 1)REGISTRAR AUTOMOVIL
# 2)REGISTRO MANTENIMIENTO
# 3)COSULTAR AUTOMOVIL
# 4)SALIR
# 4
# CERRANDO SESION
