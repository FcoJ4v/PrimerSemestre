# %%
from IPython.core.display import publish_display_data
import numpy as np
plat = 120000
gold = 80000
silver = 50000
banderin_entradas = False
banderin_rut = False
lista_asientos = []
lista_rut=[]
lista_entrada = []
lista_cantidad = []
lista_total = []
contando = 0



banderin_entradas = False

def compro_entradas(list):
  lista_ubi = []
  lista_ubi = list

  entradas = int(input("INGRESE LA CANTIDAD DE ENTRADAS A COMPRAR (MAXIMO 3)\n"))
  if(entradas >=1 and entradas <=3):
    banderin_entradas = True
    for i in range(1,101):
      lista_asientos.append(str(i))
    lista_asientos
    arreglo_multidim = np.array([lista_asientos[0:10],
                                lista_asientos[10:20],
                                 lista_asientos[20:30],
                                 lista_asientos[30:40],
                                 lista_asientos[40:50],
                                 lista_asientos[60:70],
                                 lista_asientos[80:90],
                                 lista_asientos[90:100]])
    print("""
                          ESCENARIO
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          """.format(arreglo_multidim[0][0],
                    arreglo_multidim[0][1],
                    arreglo_multidim[0][2],
                    arreglo_multidim[0][3],
                    arreglo_multidim[0][4],
                    arreglo_multidim[0][5],
                    arreglo_multidim[0][6],
                    arreglo_multidim[0][7],
                    arreglo_multidim[0][8],
                    arreglo_multidim[0][9],
                    arreglo_multidim[1][0],
                    arreglo_multidim[1][1],
                    arreglo_multidim[1][2],
                    arreglo_multidim[1][3],
                    arreglo_multidim[1][4],
                    arreglo_multidim[1][5],
                    arreglo_multidim[1][6],
                    arreglo_multidim[1][7],
                    arreglo_multidim[1][8],
                    arreglo_multidim[1][9],
                     arreglo_multidim[2][0],
                    arreglo_multidim[2][1],
                    arreglo_multidim[2][2],
                    arreglo_multidim[2][3],
                    arreglo_multidim[2][4],
                    arreglo_multidim[2][5],
                    arreglo_multidim[2][6],
                    arreglo_multidim[2][7],
                    arreglo_multidim[2][8],
                    arreglo_multidim[2][9],
                    arreglo_multidim[3][0],
                    arreglo_multidim[3][1],
                    arreglo_multidim[3][2],
                    arreglo_multidim[3][3],
                    arreglo_multidim[3][4],
                    arreglo_multidim[3][5],
                    arreglo_multidim[3][6],
                    arreglo_multidim[3][7],
                    arreglo_multidim[3][8],
                    arreglo_multidim[3][9],
                     arreglo_multidim[4][0],
                    arreglo_multidim[4][1],
                    arreglo_multidim[4][2],
                    arreglo_multidim[4][3],
                    arreglo_multidim[4][4],
                    arreglo_multidim[4][5],
                    arreglo_multidim[4][6],
                    arreglo_multidim[4][7],
                    arreglo_multidim[4][8],
                    arreglo_multidim[4][9],
                     arreglo_multidim[5][0],
                    arreglo_multidim[5][1],
                    arreglo_multidim[5][2],
                    arreglo_multidim[5][3],
                    arreglo_multidim[5][4],
                    arreglo_multidim[5][5],
                    arreglo_multidim[5][6],
                    arreglo_multidim[5][7],
                    arreglo_multidim[5][8],
                    arreglo_multidim[5][9],
                     arreglo_multidim[6][0],
                    arreglo_multidim[6][1],
                    arreglo_multidim[6][2],
                    arreglo_multidim[6][3],
                    arreglo_multidim[6][4],
                    arreglo_multidim[6][5],
                    arreglo_multidim[6][6],
                    arreglo_multidim[6][7],
                    arreglo_multidim[6][8],
                    arreglo_multidim[6][9],
                     arreglo_multidim[7][0],
                    arreglo_multidim[7][1],
                    arreglo_multidim[7][2],
                    arreglo_multidim[7][3],
                    arreglo_multidim[7][4],
                    arreglo_multidim[7][5],
                    arreglo_multidim[7][6],
                    arreglo_multidim[7][7],
                    arreglo_multidim[7][8],
                    arreglo_multidim[7][9]))
 
    ubicacion = input("SELECCIONE UNA UBICACION\n")
    posicion = lista_ubi.index(ubicacion)
    lista_ubi[posicion] = 'X'
    print("... compra terminada")

    if(ubicacion >=1 and ubicacion <=20):
      calculo = (entradas * plat) 
      print("El VALOR TOTAL DE LA ENTRADA PLATINUM ES: ", calculo)
    elif (ubicacion >=21 and ubicacion <=50):
      calculo = (entradas * gold)
      print("EL VALOR TOTAL DE LA ENTRADA GOLD  ES: ", calculo)
    elif (ubicacion >=51 and ubicacion <=100):
      calculo = (entradas * silver )
      print("EL VALOR TOTAL DE LA ENTRADA SILVER ES:", calculo) 
      rut = input("INGRESE SU RUT (SIN GUION, SIN PUNTO Y SIN DIGITO VERIFICADOR EJEMPLO: 1234567K):\n")
      if banderin_rut:
        lista_rut.append(rut)
      
      
      for caracter in rut:
        if len(caracter) >= 1 and len(caracter) <=9:
          banderin_rut=True
          
          print("rut valido")
        
      else:
        print("rut no valido")

    
  else:
    print("NUMERO DE ENTRADA NO VALIDA.\n")


  def muestro_asientos():
    #comprar_asiento(lista_asientos) 
    for i in range(1,101):
      lista_asientos.append(str(i))
    lista_asientos
    arreglo_multidim = np.array([lista_asientos[0:10],
                                lista_asientos[10:20],
                                 lista_asientos[20:30],
                                 lista_asientos[30:40],
                                 lista_asientos[40:50],
                                 lista_asientos[60:70],
                                 lista_asientos[80:90],
                                 lista_asientos[90:100]])
    print("""
                          ESCENARIO
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          |	{}	{}	{}	{}	{}	{}	{}	{}	{}	{} |
          """.format(arreglo_multidim[0][0],
                    arreglo_multidim[0][1],
                    arreglo_multidim[0][2],
                    arreglo_multidim[0][3],
                    arreglo_multidim[0][4],
                    arreglo_multidim[0][5],
                    arreglo_multidim[0][6],
                    arreglo_multidim[0][7],
                    arreglo_multidim[0][8],
                    arreglo_multidim[0][9],
                    arreglo_multidim[1][0],
                    arreglo_multidim[1][1],
                    arreglo_multidim[1][2],
                    arreglo_multidim[1][3],
                    arreglo_multidim[1][4],
                    arreglo_multidim[1][5],
                    arreglo_multidim[1][6],
                    arreglo_multidim[1][7],
                    arreglo_multidim[1][8],
                    arreglo_multidim[1][9],
                     arreglo_multidim[2][0],
                    arreglo_multidim[2][1],
                    arreglo_multidim[2][2],
                    arreglo_multidim[2][3],
                    arreglo_multidim[2][4],
                    arreglo_multidim[2][5],
                    arreglo_multidim[2][6],
                    arreglo_multidim[2][7],
                    arreglo_multidim[2][8],
                    arreglo_multidim[2][9],
                    arreglo_multidim[3][0],
                    arreglo_multidim[3][1],
                    arreglo_multidim[3][2],
                    arreglo_multidim[3][3],
                    arreglo_multidim[3][4],
                    arreglo_multidim[3][5],
                    arreglo_multidim[3][6],
                    arreglo_multidim[3][7],
                    arreglo_multidim[3][8],
                    arreglo_multidim[3][9],
                     arreglo_multidim[4][0],
                    arreglo_multidim[4][1],
                    arreglo_multidim[4][2],
                    arreglo_multidim[4][3],
                    arreglo_multidim[4][4],
                    arreglo_multidim[4][5],
                    arreglo_multidim[4][6],
                    arreglo_multidim[4][7],
                    arreglo_multidim[4][8],
                    arreglo_multidim[4][9],
                     arreglo_multidim[5][0],
                    arreglo_multidim[5][1],
                    arreglo_multidim[5][2],
                    arreglo_multidim[5][3],
                    arreglo_multidim[5][4],
                    arreglo_multidim[5][5],
                    arreglo_multidim[5][6],
                    arreglo_multidim[5][7],
                    arreglo_multidim[5][8],
                    arreglo_multidim[5][9],
                     arreglo_multidim[6][0],
                    arreglo_multidim[6][1],
                    arreglo_multidim[6][2],
                    arreglo_multidim[6][3],
                    arreglo_multidim[6][4],
                    arreglo_multidim[6][5],
                    arreglo_multidim[6][6],
                    arreglo_multidim[6][7],
                    arreglo_multidim[6][8],
                    arreglo_multidim[6][9],
                     arreglo_multidim[7][0],
                    arreglo_multidim[7][1],
                    arreglo_multidim[7][2],
                    arreglo_multidim[7][3],
                    arreglo_multidim[7][4],
                    arreglo_multidim[7][5],
                    arreglo_multidim[7][6],
                    arreglo_multidim[7][7],
                    arreglo_multidim[7][8],
                    arreglo_multidim[7][9]))

  def asistentes():
    print('BIENVENIDO A LA OPCION ASISTENTES')

    arreglin_asistentes = np.zeros((20))
    for i in range(100):
        
        arreglin_asistentes[i] = valor
        print(f'Datos: {i}')
        print(arreglin_asistentes[i])
    print("""
         
        DATO COMPLETO:{} {} {}
        DATO COMPLETO:{} {} {}
  """.format(lista_rut,arreglin_asistentes[1],
             lista_rut,arreglin_asistentes[2],
             lista_rut,arreglin_asistentes[3],
             lista_rut,arreglin_asistentes[4],
             lista_rut,arreglin_asistentes[5],
             lista_rut,arreglin_asistentes[6]))

  def ganancia_tot():
    print("\tBIENVENIDO A GANANCIAS TOTALES")
    arreglin_ganancias = np.zeros((20))
    for i in range(4):
        
        arreglin_ganancias[i] = valor
        print(f'Datos: {i}')
        print(arreglin_ganancias[i])
    print("""
         
        PLATINUM:{} {} 
        GOLD:{} {}
        SILVER:{} {}
        TOTAL: {} {}
  """.format(lista_cantidad,lista_total,arreglin_ganancias[1],
            lista_cantidad,lista_total,arreglin_ganancias[2],
            lista_cantidad,lista_total,arreglin_ganancias[3],
            lista_cantidad,lista_total,arreglin_ganancias[4],
            lista_cantidad,lista_total,arreglin_ganancias[5],
            lista_cantidad,lista_total,arreglin_ganancias[6]))
