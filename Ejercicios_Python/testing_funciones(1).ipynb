# %%
import numpy as np
lista_asiento = []


for x in range(1,43):
  lista_asiento.append(str(x))

def ver_asiento():
      lista_asiento
      arreglin_asiento = np.array([lista_asiento[0:6],
                                    lista_asiento[6:12],
                                    lista_asiento[12:18]])
      print("""
      |	{}	{}	{}		{}	{}  {}	|
      |								|
      |	{}	{}	{}		{}	{}	{}	|
      |								|
      |	{}  {}  {}		{}	{}	{}	|
      |								|
      |	19	20	21		22	23	24	|
      |								|
      |	25	26	27		X	29	30	|
      |______________________                      ________________________|
      |______________________                      ________________________|
      |	X	32	33		34	35	36	|
      |								|
      |								|
      |	X	38	X		40	41	X	|

      """.format( arreglin_asiento[0][0],
                  arreglin_asiento[0][1],
                  arreglin_asiento[0][2],
                  arreglin_asiento[0][3],
                  arreglin_asiento[0][4],
                  arreglin_asiento[0][5],
                  arreglin_asiento[1][0],
                  arreglin_asiento[1][1],
                  arreglin_asiento[1][2],
                  arreglin_asiento[1][3],
                  arreglin_asiento[1][4],
                  arreglin_asiento[1][5]))
