# %%
variable_texto = input('ingrese: ')
ip = input('ip')
if(variable_texto == 'estudiante'):
  print('usted es estudiante')
  flag_estudiante = False
if(variable_texto=='estudiante'):
  flag_estudiante = True
if flag_estudiante:
  print('saludos alumno')
elif (flag_estudiante and ip=='duoc'):
  print('eres del mejor ip')
else:
  print('no es alumno')
# Out:
# ingrese: jojo
# ipduoc+
# saludos alumno
