# %%
y=4
x=2
y = y/x

print(y)
# Out:
# 2.0

# %%
z= y = x =1
print(x,y,z, sep="*")
# Out:
# 1*1*1

# %%
y = 2 + 3 * 5
print (y)
# Out:
# 17

# %%
z = 1 / 2  +3 // 3 + 4 **2
print(z)
# Out:
# 17.5

# %%
1 // 2 * 3
# Out:
# 0

# %%
x=11
y=4

print (y % x)
# Out:
# 4
