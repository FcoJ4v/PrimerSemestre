# %%
bandera_estudiantre = False
bandera_estudiante = False
bandera_adulto_mayor = False

contador_transporte = 0
contador_acceso = 0
acumulador = 0

#respuesta = input("eres estudiante? 1)si 2)no")
respuesta = input('Eres 1)Estudiante 2)Docente')
respuesta_edad = int(input('Ingrese su edad'))
if (respuesta_edad>=65):
  bandera_adulto_mayor = True
if(respuesta == "1"):
  bandera_estudiante = True
  print('Se habilito el acceso al estudiante')
elif (respuesta == "2"):
    bandera_docente = True
    print("Se habilito el acceso al docente")
#se da acceso a valores prefentes en transporte

if(bandera_estudiante):
  print("paga escolar 250")
  contador_transporte = contador_transporte +1
  acumulador = acumulador + 250
elif (bandera_adulto_mayor):
    contador_transporte = contador_transporte+1
    print("paga preferencial 100")
    acumulador = acumulador +100
else:
  contador_transporte = contador_transporte+1
  acumulador = acumulador + 1000

if(bandera_estudiante or bandera_docente):
  print('puede acceder a la sede')
  contador_acceso = contador_acceso +1

print ("personas que accedieron {},contador transporte {},monto total ${}".format(contador_acceso,contador_transporte,acumulador))
# Out:
# Eres 1)Estudiante 2)Docente2
# Ingrese su edad45
# Se habilito el acceso al docente
# puede acceder a la sede
# personas que accedieron 1,contador transporte 1,+monto total $1000
