# %% [markdown]
# 1. Una emprendedora comenzó a vender identificaciones para mascotas con entrega a domicilio. Estas son metálicas con diversas formas. Para ello creó una tienda online donde los clientes solicitan los productos y la grabación de la placa metálica. Cada identificación tiene un precio, según el tamaño de la placa:
# Pequeña: 3.500
# Mediana: 4.500
# Grande: 5.500
#
# El despacho a domicilio tiene un recargo de $2000 y si la compra es superior a 10.000 el despacho es gratis.

# %%
#Francisco Alvarez 006D

placa_p = 3500
placa_m = 4500
placa_g = 5500
despacho_precio = 2000
bandera_selec1 = False
bandera_selec2 = False
bandera_selec3 = False
bandera_despacho = False
print('     Bienvenido a nuestro sistema de ventas!\n')
seleccion = int(input(f'Seleccione el tamaño de la placa deseada:\n 1) Pequeño: ${placa_p}\n 2) Mediana: ${placa_m}\n 3) Grande: ${placa_g}\n'))
#validacion de la seleccion, que sean los numeros de la opcion que se solicita
while(seleccion>3 or seleccion <=0):
  print('opcion ingresada no valida')
  seleccion = int(input(f'Seleccione el tamaño de la placa deseada:\n 1) Pequeño: ${placa_p}\n 2) Mediana: ${placa_m}\n 3) Grande: ${placa_g}\n')) 
else: 
 if(seleccion == 1):
  bandera_selec1 = True
  print(f'selecciono la opcion:\n-Placa Pequeña \n')
 elif(seleccion == 2):
    bandera_selec2 = True
    print(f'selecciono la opcion:\n-Placa Mediana\n') 
 elif(seleccion ==3):
      bandera_selec3 = True
      print(f'selecciono la opcion:\n-Placa Grande\n')

cantidad = int(input('Ingrese la cantidad deseada: \n'))
grabacion_placa = int(input('¿Desea agregar una grabacion en la placa?\n 1)SI \n 2)NO\n'))
despacho = int(input('¿Desea despacho  domicilio?\n 1)SI \n 2)NO\n'))
if(despacho ==1):
    bandera_despacho = True
elif(despacho ==2):
    bandera_despacho = False
else:
 print('opcion no valida')

#seleccion placa pequeña con calculo de despacho
if (bandera_selec1 and bandera_despacho):
  total = (cantidad * placa_p)
  total_despacho = (total + despacho_precio)
  #si el total sale mas de $10.000 despacho costo 0
  if(total > 10000):
    print(f'Detalle Compra:\n-Tipo Placa: Pequeña\n-Valor placa: ${placa_p}\n-Cantidad: {cantidad}\n-Despacho: $0 \n-El total de su compra es: ${total}\n')
  else:
    print(f'Detalle Compra:\n-Tipo Placa: Pequeña\n-Valor placa: ${placa_p}\n-Cantidad: {cantidad}\n-Despacho: ${despacho_precio} \n-El total de su compra es: ${total_despacho}\n')
  #opcion de la placa pequeña sin calculo de despacho
elif(bandera_selec1 and bandera_despacho==False):
  bandera_selec1 = True
  total = (cantidad * placa_p)
  print(f'Detalle Compra:\n-Tipo Placa: Pequeña\n-Valor placa: ${placa_p}\n-Cantidad: {cantidad}\n-Despacho: NO \n-El total de su compra es: ${total}\n')

#seleccion placa mediana con calculo de despacho
elif (bandera_selec2 and bandera_despacho):
  bandera_selec2 = True
  total = (cantidad * placa_m)
  total_despacho = (total + despacho_precio)
  #si el total sale mas de $10.000 despacho costo 0 para la opcion de placa mediana
  if(total > 10000):
    print(f'Detalle Compra:\n-Tipo Placa: Mediana\n-Valor placa: ${placa_m}\n-Cantidad: {cantidad}\n-Despacho: $0 \n-El total de su compra es: ${total}\n')

  else:
    print(f'Detalle Compra:\n-Tipo Placa: Mediana\n-Valor placa: ${placa_m}\n-Cantidad: {cantidad}\n-Despacho: ${despacho_precio} \n-El total de su compra es: ${total_despacho}\n')
  #seleccion placa mediana sin calculo de despacho
elif(bandera_selec2 and bandera_despacho==False):
  bandera_selec2 = True
  total = (cantidad * placa_m)
  print(f'Detalle Compra:\n-Tipo Placa: Mediana\n-Valor placa: ${placa_m}\n-Cantidad: {cantidad}\n-Despacho: NO \n-El total de su compra es: ${total}\n')

  #seleccion placa grande con calculo de despacho
elif (bandera_selec3 and bandera_despacho):
  bandera_selec3 = True
  bandera_despacho = True
  total = (cantidad * placa_g)
  total_despacho = (total + despacho_precio)
  #si el total sale mas de $10.000 despacho costo 0 para la opcion de placa grande
  if(total > 10000):
    print(f'Detalle Compra:\n-Tipo Placa: Grande\n-Valor placa: ${placa_g}\n-Cantidad: {cantidad}\n-Despacho: $0 \n-El total de su compra es: ${total}\n')

  else:
    print(f'Detalle Compra:\n-Tipo Placa: Grande\n-Valor placa: ${placa_g}\n-Cantidad: {cantidad}\n-Despacho: ${despacho_precio} \n-El total de su compra es: ${total_despacho}\n')
  #seleccion placa grande sin calculo de despacho
elif(bandera_selec3 and bandera_despacho==False):
  bandera_selec3 = True
  bandera_despacho = True
  total = (cantidad * placa_g)
  print(f'Detalle Compra:\n-Tipo Placa: Grande\n-Valor placa: ${placa_g}\n-Cantidad: {cantidad}\n-Despacho: NO \n-El total de su compra es: ${total}\n')  

else:
  #si ingreso una opcion no valida muestre por pantalla lo siguiente: 
  print('datos ingresados no validos.')
# Out:
#      Bienvenido a nuestro sistema de ventas!
#
# Seleccione el tamaño de la placa deseada:
#  1) Pequeño: $3500
#  2) Mediana: $4500
#  3) Grande: $5500
# 2
# selecciono la opcion:
# -Placa Mediana
#
# Ingrese la cantidad deseada:
# 4
# ¿Desea agregar una grabacion en la placa?
#  1)SI
#  2)NO
# 1
# ¿Desea despacho  domicilio?
#  1)SI
#  2)NO
# 1
# Detalle Compra:
# -Tipo Placa: Mediana
# -Valor placa: $4500
# -Cantidad: 4
# -Despacho: $0
# -El total de su compra es: $18000

# %% [markdown]
# 2. En una automotora se realizan 4 tipos de revisiones a los vehículos:
# Frenos 1.500
# Aceite 1.000
# Motor 2.000
# Luces 3.000
# Determine el total a pagar por un cliente que puede requerir una o más de estas revisiones.
#
# Considere que si el auto es de la marca Mazda o Toyota se le realizará un 10% de descuento.

# %%
frenos = 1500
aceite = 1000
motor = 2000
luces = 3000
marca = " "
acum_freno = 0
acum_aceite = 0
acum_motor = 0
acum_luces = 0

print('        Bienvenido al sistema de revision de vehiculos!\n')
marca = input('Ingrese la marca de su vehiculo\n')
while True:
  if (marca !="mazda" and marca !="toyota"):
    seleccion = int(input('Seleccione el tipo de revision que necesita:\n1)Frenos:$1.500\n2)Aceite:$1.000\n3)Motor:$2.000\n4)Luces:$3.000\n5)SALIR\n'))
  
    while(seleccion<=0 or seleccion>=6 ):
      print('opcion ingresada no valida.\n')
      seleccion = int(input('Seleccione el tipo de revision que necesita:\n1)Frenos:$1.500\n2)Aceite:$1.000\n3)Motor:$2.000\n4)Luces:$3.000\n5)SALIR\n'))
    if(seleccion==1):
      acum_freno = acum_freno + frenos
      otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif(seleccion ==2):
      acum_aceite = (acum_aceite + aceite)
      otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif(seleccion ==3):
      acum_motor = (acum_motor + motor)
      otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif(seleccion ==4):
        acum_luces=(acum_luces + luces)
        otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif (seleccion ==5 ):break
  if (otra_seleccion == 2 and marca !="mazda" and marca!="toyota"):

    total = (acum_luces+acum_motor+acum_aceite+acum_freno)
    print(f'Vehiculo:{marca}\nEl total a pagar es: ${total}')
    break

  if (marca =="mazda" or marca=="toyota"):
    seleccion = int(input('Seleccione el tipo de revision que necesita:\n1)Frenos:$1.500\n2)Aceite:$1.000\n3)Motor:$2.000\n4)Luces:$3.000\n5)SALIR\n'))
  
    while(seleccion<=0 or seleccion>=6 ):
      print('opcion ingresada no valida.\n')
      seleccion = int(input('Seleccione el tipo de revision que necesita:\n1)Frenos:$1.500\n2)Aceite:$1.000\n3)Motor:$2.000\n4)Luces:$3.000\n5)SALIR\n'))
    if(seleccion==1):
      acum_freno = acum_freno + frenos
      otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif(seleccion ==2):
      acum_aceite = (acum_aceite + aceite)
      otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif(seleccion ==3):
      acum_motor = (acum_motor + motor)
      otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif(seleccion ==4):
        acum_luces=(acum_luces + luces)
        otra_seleccion = int(input('¿Desea otra tipo de revision?\n1) SI 2)NO\n'))
    elif (seleccion ==5 ):break
  
  
  if (otra_seleccion == 2):

    total = int(acum_luces+acum_motor+acum_aceite+acum_freno)
    calc_porcentaje = int(acum_luces+acum_motor+acum_aceite+acum_freno) * 0.10
    dcto = int(total - calc_porcentaje)
    print (f'Vehiculo: {marca}\nTotal:${total}\nDescuento:${calc_porcentaje}\nTotal a pagar:${dcto}')
    break
# Out:
#         Bienvenido al sistema de revision de vehiculos!
#
# Ingrese la marca de su vehiculo
# asdasd
# Seleccione el tipo de revision que necesita:
# 1)Frenos:$1.500
# 2)Aceite:$1.000
# 3)Motor:$2.000
# 4)Luces:$3.000
# 5)SALIR
# 5
