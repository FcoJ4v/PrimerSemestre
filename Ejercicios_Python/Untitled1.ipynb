# %%
estreno = 4800
normal = 2900
palomita_p= 2500
palomita_m=4500
palomita_g=7800
bebida_p=1000
bebida_m=1250
bebida_g=2000
cliente = " "
cliente_duoc = 0
palomitas = " "
bebida = " "
cant_palomita = 0
cant_bebida = 0
tipo_palomita = 0
tipo_bebida = 0
calculo1= 0
porcentaje = 0.30
entrada=0
cant_entrada= 0

print("Bienvenido al sistema de ventas de CineDUOC. \n")
cliente  = input("Seleccione: 1) DUOC - 2(General \n")
if (cliente == "si"):
  cliente_duoc = int(input("Seleccione una opcion: 1)estudiante - 2)funcionario \n"))
elif(cliente=="no"):


  entrada = int(input("seleccione una opcion de entrada : 1)Estreno - 2)Normal \n"))
cant_entrada = int(input("Ingrese la cantidad de entradas: \n"))
palomitas = input("¿Desea agregar palomitas de maiz a su pedido: \n")

if(palomitas == "si"):
  print("\n1) Palomita pequeña -> $2500")
  print("2) Palomita mediana -> $4500")
  print("3) Palomita Grande -> $7800 \n" )
tipo_palomita = int(input("Ingresa el tipo de palomita: \n"))
cant_palomita = int(input("Ingresa la cantidad de palomitas: \n"))

bebida = input("¿Desea agregar bebida a su pedido? \n")
if(bebida=="si"):
  print("\n1) Bebida pequeña -> $1000")
  print("2) Bebida mediana -> $1250")
  print("3) Bebida pequeña -> $2000")
tipo_bebida=int(input("Ingrese el tipo de bebida: \n"))
cant_bebida=int(input("Ingrese la cantidad de bebida: \n"))

#calculo pequeño
if(palomitas=="si" and tipo_palomita==1 and tipo_bebida==1 and cliente=="si" and bebida=="si" ):
  porcen_calc = (estreno * porcentaje)
  desc_calc = (estreno - porcen_calc)
  calculo = ((((palomita_p)* cant_palomita + (bebida_p)*cant_bebida +desc_calc))* cant_entrada)
             
  print("El total es: $",calculo)
# Out:
# ¿Pertenece usted a DUOC?:
# si
# Seleccione una opcion: 1)estudiante - 2)funcionario
# 1
# Ingrese la cantidad de entradas:
# 2
# ¿Desea agregar palomitas de maiz a su pedido:
# si
#
# 1) Palomita pequeña -> $2500
# 2) Palomita mediana -> $4500
# 3) Palomita Grande -> $7800
#
# Ingresa el tipo de palomita:
# 1
# Ingresa la cantidad de palomitas:
# 2
# ¿Desea agregar bebida a su pedido?
# si
#
# 1) Bebida pequeña -> $1000
# 2) Bebida mediana -> $1250
# 3) Bebida pequeña -> $2000
# Ingrese el tipo de bebida:
# 1
# Ingrese la cantidad de bebida:
# 2
# El total es: $ 20720.0
