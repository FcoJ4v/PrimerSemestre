# %%
dol_aus_clp = 602.60871
dol_aus = 0
pes_arg_clp = 7.15
pes_arg = 0
clp_yen = 6.45 
yen = 0


seleccion = float(input('Ingrese el tipo de moneda para convertir a peso chileno:\n1)Dolar Australiano\n2)Peso Argentino\n3)Yen\n'))
if(seleccion ==1):
  dol_aus = (int(input('Ingrese la cantidad de dolares australianos a convertir:\n')))
  calculo= int(dol_aus * dol_aus_clp)
  print(f'el monto calculado es:${calculo} CLP')
elif(seleccion ==2):
  pes_arg = (int(input('Ingrese la cantidad de pesos Argentinos a convertir:\n')))
  calculo = (int(pes_arg_clp*pes_arg))
  print(f'el monto calculado es:${calculo} CLP')
elif(seleccion ==3):
  yen = (int(input('Ingrese la cantidad de yenes a convertir:\n')))
  calculo = (int(yen*clp_yen))
  print(f'el monto calculado es:${calculo} CLP')
else:
  print('Opcion ingresada no valida.')
# Out:
# Ingrese el tipo de moneda para convertir a peso chileno:
# 1)Dolar Australiano
# 2)Peso Argentino
# 3)Yen
# 4
# Opcion ingresada no valida.
