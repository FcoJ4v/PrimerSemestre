# %%
a = 5
b = 0
try:
  c=a/b
  print("{} / {} = {}".format(a,b,a/b))
except :
  print("=== WARNING ===")
# Out:
# === WARNING ===

# %%
a = 5
b = "5"
try:
  c=a/b
  print("{} / {} = {}".format(a,b,a/b))
except :
  print("=== WARNING ===")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2e3c01907703> in <module>()
#       1 a = 5
#       2 b = "5"
# ----> 3 c=a/b
#       4 print("{} / {} = {}".format(a,b,a/b))
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
try:
  opcion = int(input("1) Opcion 1\n2) Opcion 2\n3) Opcion 3\n4) Salir\n"))
  if(opcion ==1):
    print("Tomaste la opcion 1")
except:
  print("algo paso ojo")
# Out:
# 1) Opcion 1
# 2) Opcion 2
# 3) Opcion 3
# 4) Salir
# asd
# algo paso ojo

# %%
opcion = 999
try:
  while (opcion !=4):
    num1 = int(input("Ingrese un numero.: "))
    num2 = int(input("Ingrese un numero.: "))
    opcion = int(input("1) Opcion Division\n2) Opcion 2\n3) Opcion 3\n4) Salir\n"))
    if(opcion ==1):
        print("Tomaste la opcion 1")
    print("{} / {} = {}".format(num1,num2,num1/num2))
except ZeroDivisionError:
  print("no sea... no ingrese 0")
  print("Algo paso ojo: ZeroDivisionError")
except ValueError:
  print("Algo paso ojo: ValueError")
# Out:
# Ingrese un numero.: 5
# Ingrese un numero.: 4
