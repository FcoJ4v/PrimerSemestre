# %%
i = 2
while i >=0:
  print("*")
  i -=2
# Out:
# *
# *

# %%
for i in range(-1,1):
  print("#")
# Out:
# #
# #

# %%
z = 10
y = 0
x = z > y or z == y
print (x)
# Out:
# True

# %%
lst  = [3,1,-1]
lst[-1] = lst[-2]
print (lst)
# Out:
# [3, 1, 1]

# %%
vals = [0,1,2]
vals [0], vals[1] = vals [1],vals[2]
print (vals)
# Out:
# [1, 2, 2]

# %%
nums = []
vals = nums
vals.append(1)
print (vals)
# Out:
# [1]

# %%
nums = []
vals = nums[:]
vals.append(1)
print (vals)
# Out:
# [1]

# %%
lst = [0 for i in range (1,3)]
print (lst)
# Out:
# [0, 0]

# %%
lst = [0,1,2,3]
x = 1
for elem in lst:
  x *= elem
print (x)
# Out:
# 0

# %%
from _typeshed import OpenTextModeUpdating
def fun (in = 2, out = 3):
  return in  * out
print(fun(3))
# Out:
#   File "<ipython-input-17-51ea68e7b7d4>", line 2
#     def fun (in = 2, out = 3):
#               ^
# SyntaxError: invalid syntax

# %%
tup = (1, )+ (1, )
tup = tup + tup
print(len(tup))
# Out:
# 4

# %%
try:
  first_prompt= input("ingresa el primer valor:")
  a = len(first_prompt)
  second_prompt = input("ingresa el segundo valor:")
  b  = len(second_prompt) * 2
  print(a/b)


except ZeroDivisionError:

    print("No divida por 0")
except ValueError:
  print ("Valor incorrecto")
except:
  print("Error.Error.Error")
# Out:
# ingresa el primer valor:Kangaroo
# ingresa el segundo valor:0
# 4.0

# %%
value = input("ingresa un valor")
print(10/value)
# Out:
# ingresa un valor0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1a8a5130c488> in <module>()
#       1 value = input("ingresa un valor")
# ----> 2 print(10/value)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
def function(x = 0):
  return x
print (x)
# Out:
# 0

# %%
def f(x):
  if x == 0:
    return 0
  return x + f(x - 1)
print(f(3))
# Out:
# 6

# %%
def fun(x):
  x +=1
  return x

x = 2
x = fun (x + 1)
print(x)
# Out:
# 4

# %%
dct = {}
lst = ['a', 'b', 'c', 'd']
for i in range(len(lst) - 1):
    dct[lst[i]] = (lst[i],)
for i in sorted(dct.keys()):
  k = dct[i]
  print (k)
# Out:
# ('a',)
# ('b',)
# ('c',)

# %%
def func(a,b):
  return a ** a
print (func(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-65fb33196066> in <module>()
#       1 def func(a,b):
#       2   return a ** a
# ----> 3 print (func(2))
#
# TypeError: func() missing 1 required positional argument: 'b'

# %%
def func1(a):
  return a ** a
def func2(a):
  return func1(a) * func1(a)
print(func2(2))
# Out:
# 16

# %%
def fun(x):
  if x % 2 ==0:
    return 1
  else:
    return

print(fun(fun(2))+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-2674a473884f> in <module>()
#       5     return
#       6
# ----> 7 print(fun(fun(2))+1)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
def fun(x):

  global y
  y = x * x
  return y

fun(2)
print(y)
# Out:
# 4

# %%
def any():
  print(var + 1,end='')
var = 1
any()
print(var)
# Out:
# 21

# %%
tuple[1] = tuple[1] + tuple[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-e92353ee8486> in <module>()
# ----> 1 tuple[1] = tuple[1]
#
# TypeError: 'type' object is not subscriptable

# %%
def fun(x, y, z):
  return x+2 * y + 3 *z
print(fun(0,z=1,y=3))
# Out:
# 9

# %%
def fun(inp =2, out=3):
  return inp * out
print(fun(out=2))
# Out:
# 4

# %%
dct = {'one':'two','three':'one','two':'three'}
v = dct['one']
for k in range(len(dct)):
  v=dct[v]
print(v)
# Out:
# two

# %%
tup  = (1,2,3,4,8)
tup = tup[1:-1]
tup = tup[0]
print(tup)
# Out:
# 2

# %%
lst = [1,2]

for v in range(2):
  lst.insert(-1, lst[v])
print(lst)
# Out:
# [1, 1, 1, 2]

# %%
nums = [1,2,3]
vals  = nums

print(nums)
print(vals)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
def funcl(a):
  return None
def func2(a):
  return func1(a) * func1(a)
print(func2(2))
# Out:
# 16

# %%
1//2
# Out:
# 0

# %%
def func(a,b):
  return b ** a

print(func(b=2,2))
# Out:
#   File "<ipython-input-60-c9a0a06fec99>", line 4
#     print(func(b=2,2))
#                   ^
# SyntaxError: positional argument follows keyword argument

# %%
z = 0
y = 10
x = y < z and z > y or y > z and z < y
print(x)
# Out:
# True

# %%
list = [x * x for x in range (5)]
def fun(lst):
    del lst[lst[2]]
    return lst

print(fun(list))
# Out:
# [0, 1, 4, 9]

# %%
x = 1
y = 2
x, y, z = x, x, y
z,y,z = x,y,z
print(x,y,z)
# Out:
# 1 1 2

# %%
a = 1
b =  0
a = a ^ b
b = a ^ b
a = a ^ b
print(a,b)
# Out:
# 0 1

# %%
def fun(x):
  if x % 2 ==0:
    return 1
  else:
    return 2
print(fun(fun(2) ))
# Out:
# 2

# %%
nums = [1,2,3]
vals = nums
del vals[:]
print(vals)
print (nums)
# Out:
# []
# []

# %%
x = int(input())
y = int(input())
x = x % y
x = x % y
y = y % x
print (y)
# Out:
# 3
# 2
# 0

# %%
y = input()
x = input()
print(x + y)
# Out:
# 3
# 6
# 63

# %%
print("a","b","c", sep = "sep")
# Out:
# asepbsepc

# %%
x = 1 // 5 + 1 / 5

print(x)
# Out:
# 0.2

# %%
x = float(input())
y = float(input())
print(y ** (1 / x))
# Out:
# 2
# 4
# 2.0

# %%
dct = { 'uno':'dos','tres':'uno','dos':'tres'}
v = dct['tres']

for k in range (len(dct)):
  v = dct[v]
print(v)
# Out:
# uno

# %%
def fun (x, y):
  if x == y:
    return x
  else:
    return fun(x, y-1)
print(fun(0,3))
# Out:
# 0

# %%
i = 0
while i < i + 2:
  i += 1
  print("*")
else:
  print("*")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ...

# %%
tup = (1,2,4,8)
tup= tup[-2:-1]
tup  = tup[-1]
print(tup)
# Out:
# 4

# %%
dd = {"1":"0","0":"1"}
for x in dd.vals():
  print(x, end="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-1e00160a4e11> in <module>()
#       1 dd = {"1":"0","0":"1"}
# ----> 2 for x in dd.vals():
#       3   print(x, end="")
#
# AttributeError: 'dict' object has no attribute 'vals'

# %%
dct = {}
dct['1'] = (1, 2)
dct['2'] = (2,1)
for x in dct.keys():
  print(dct[x][1], end='')
# Out:
# 21

# %%
def fun(inp=2,out=3):
  return inp * out
print(fun(out=2))
# Out:
# 4

# %%
lst = [[x for x in range(3)] for y in range(3)]

for r in range(3):
  for c in range(3):
    if lst[r][c] % 2  != 0:
      print("#")
# Out:
# #
# #
# #

# %%
banderas = True
while banderas:
    print("Sentencias de bloque")
    opcion = input("Desea salir")
    if opcion =="salir":
      bandera = False

    contador = contador+1

# %%
while contador <3:
  opcion = input("Desea salir")
if opcion("salir"):
    bandera = False
    contador = contador + 1

# %%
bandera = True
contador = 0
while (contador <3 and bandera):

  contraseña = input("Ingrese una contraseña")
  if contraseña == "123":
    bandera = False
    print("bienvenido al sistema")
    contador=+1
# Out:
# Ingrese una contraseñaa
# Ingrese una contraseñaa
# Ingrese una contraseña123
# bienvenido al sistema

# %%
bandera = False
contador = 0
#not es negacion de bandera
while (contador <3 and not bandera):

  contraseña = input("Ingrese una contraseña")
  if contraseña == "123":
    bandera = True
    print("bienvenido al sistema")
    contador=+1

# %%
bandera_acceso = False
contador = 0
#not es negacion de bandera
while (contador <3 and not bandera_acceso):
  password = input("Ingrese una contraseña")
  if password == "123":
    bandera_acceso = True
  contador=contador +1
lista=[1,2,3]
if bandera_acceso:
  print("Bienvenido a nuestro SISTEMA")
  """
  for i in "Hola mundo":
      print(i)"""
  for i in range(3):
    print(lista[i])
# Out:
# Ingrese una contraseña123
# Bienvenido a nuestro SISTEMA
# 1
# 2
# 3
