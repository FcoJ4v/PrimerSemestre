# %%
import numpy as np
import random as rd

banderin_tipo_vehiculo = False
banderin_patente = False
banderin_marca = False
banderin_multas = False
banderin_precio = False
banderin_fecha_reg_vehi = False
banderin_duenio = False
lista_tipo_vehiculo = []
lista_patente = []
lista_marca = []
lista_precio = []
lista_multas = []
lista_fecha_reg_vehi = []
lista_duenio = []


def opc_grabar():
      print("\t Bienvenido a la opcion GRABAR.\n")
      tipo_Vehiculo = input("Ingrese el tipo de vehiculo:\n")
      patente = input("Ingrese la patente del vehiculo:\n")
      marca = input("Ingrese la marca del vehiculo:\n")
      precio = int(input('Ingrese el precio del vehiculo\n'))
      multas = input("Ingrese Multas (Monto y Fecha (DD/MM/AA)):\n")
      fecha_reg_vehiculo = input("Ingrese fecha de registro del vehiculo:\n")
      duenio = input('Ingrese el nombre del dueño:\n')

      #validacion patente
      for formato in patente:
        if len(patente) == 6:
           banderin_patente = True
           print("Patente ingresada es valida")
           break;
           
        else:
          print("Patente ingresada no valida")   

      #validacion marca 2 y 15 caracteres y el precio sea mayor a $5.000.000.

      for caracter in marca:
       if len(caracter) >= 2 and len(caracter) <=15 and precio >=5000000:
          banderin_marca=True
          banderin_precio = True
          print("valido")
          
       else:
         print("no valido")   

      #si esta ok guarde datos de cada variable en cada lista.
      if banderin_patente:
        lista_tipo_vehiculo.append(tipo_Vehiculo)
        lista_patente.append(patente)
        lista_marca.append(marca)
        lista_multas.append(multas)
        lista_precio.append(precio)
        lista_fecha_reg_vehi.append(fecha_reg_vehiculo)
        lista_duenio.append(duenio)

def opc_buscando():
      print("\t BUSCAR AUTOMOVIL.\n")
      verifica_vehiculo = input("Ingresa la patente del vehiculo:\n")
      for ver_vehiculo in lista_patente:
        if(ver_vehiculo == verifica_vehiculo):
          print("EL VEHICULO EXISTE EN EL SISTEMA.\n")
          print(f"TIPO_VEHICULO:{lista_tipo_vehiculo[conteo]}")
          print(f"PATENTE:{lista_patente[conteo]}")
          print(f"MARCA:{lista_marca[conteo]}")
          print(f"MULTAS:{lista_multas[conteo]}")
          print(f"PRECIO:{lista_precio[conteo]}")
          print(f"FECHA_REGISTRO_VEHICULO:{lista_fecha_reg_vehi[conteo]}")
          print(f"DUEÑO:{lista_duenio[conteo]}")
          conteo = conteo +1
        else:
          print('VEHICULO INGRESADO NO SE ENCUENTRA EN EL SISTEMA')

def opc_imp_cert():
      print('BIENVENIDO A LA OPCION IMPRIMIR CERTIFICADO')

      arreglin_certificado = np.zeros((20))
      for i in range(20):
        valor = rd.randrange(1500,3500)
        arreglin_certificado[i] = valor
        print(f'Multa: {i}')
        print(arreglin_certificado[i])
      print("""
         
        Certificado:{} {} {}
        Certificado:{} {} {}
  """.format(lista_patente,lista_duenio,arreglin_certificado[1],
             lista_patente,lista_duenio,arreglin_certificado[2],
             lista_patente,lista_duenio,arreglin_certificado[3],
             lista_patente,lista_duenio,arreglin_certificado[4],
             lista_patente,lista_duenio,arreglin_certificado[5],
             lista_patente,lista_duenio,arreglin_certificado[6]))
